# %%
# Parameters
GROUP_ID = '43'
ALGORITHM = 'bt' # bt | fc | ac3 | sa | ga
PUZZLE_TYPE = 'extreme' # easy | medium | hard | extreme
PUZZLE_PATH = 'C:\\Users\\Asus\\Downloads\\AiSudokuSolver-main\\AiSudokuSolver-main\\puzzles\\extreme\\Evil-P4.txt'

# %%
from io_1 import read_puzzle, write_puzzle, build_output_filename
import numpy as np
import hashlib
import random
from random import choice
# Deterministic seed from parameters
_seed = int(hashlib.md5(f"{GROUP_ID}:{ALGORITHM}:{PUZZLE_PATH}".encode()).hexdigest()[:8], 16)

# %%
def flag_Initial(grid):
    flag = np.zeros((9,9), dtype=int)
    for i in range (0,9):
        for j in range (0,9):
            if grid[i][j] != 0:
                flag[i,j] = 1
    return flag

# %%
def fitness(grid):
    ErrorCount = 0
    total = 0
    for i in range(0,9):
        ErrorCount = (9 - len(np.unique(grid[:,i]))) + (9 - len(np.unique(grid[i,:])))
        total = total + ErrorCount
    return total

# %%
def getBlocks(grid):
    answer = []
    for r in range(3):
        for c in range(3):
            block = []
            for i in range(3):
                for j in range(3):
                    block.append(grid[3*r + i][3*c + j])
            answer.append(block)
    return answer

# %%
def fillrandom(blocks):
    for block in blocks:
        for j in range(0,9):
            if block[j] == 0:
                    block[j] = choice([i for i in range(1,10) if i not in block])
    randomgrid = []
    for block_row in range(3):       
        for row_in_block in range(3): 
            row = []
            for block_col in range(3):  
                block_index = block_row * 3 + block_col
                row.extend(blocks[block_index][row_in_block*3 : (row_in_block+1)*3])
            randomgrid.append(row)
    randomgrid = np.array(randomgrid)
    return randomgrid

# %%
def flip(gridtemp , flag):
    temporary = gridtemp.copy()
    while True:
        row1 =  random.randint(0,8)
        col1 =  random.randint(0,8)
        while True:
            r = (row1 // 3)*3 + random.randint(0,2)
            c = (col1 // 3)*3 + random.randint(0,2)
            if (r,c) != (row1,col1):
                row2 = r
                col2 = c
                break
        if flag[row1][col1] != 1 and flag[row2][col2] != 1:
            # print(f"Swapping ({row1},{col1}) with ({row2},{col2})")
            temp = temporary[row1][col1]
            temporary[row1][col1] = temporary[row2][col2]
            temporary[row2][col2] = temp
            return temporary

# %%
initialgrid = read_puzzle(PUZZLE_PATH)
print(initialgrid)
grid = initialgrid.copy()
blocks = getBlocks(grid)
print(blocks)
flag = flag_Initial(grid)
# randomgrid = []
# for block_row in range(3):       
#     for row_in_block in range(3): 
#         row = []
#         for block_col in range(3):  
#             block_index = block_row * 3 + block_col
#             row.extend(blocks[block_index][row_in_block*3 : (row_in_block+1)*3])
#         randomgrid.append(row)
# randomgrid = np.array(randomgrid)
# Out:
# [[0, 0, 3, 9, 1, 4, 6, 0, 0], [6, 0, 0, 0, 0, 0, 5, 0, 4], [0, 1, 0, 0, 0, 6, 0, 9, 3], [0, 4, 2, 0, 0, 7, 0, 0, 5], [0, 3, 8, 0, 0, 0, 9, 7, 0], [9, 0, 0, 5, 0, 0, 4, 2, 0], [8, 7, 0, 2, 0, 0, 0, 4, 0], [3, 0, 6, 0, 0, 0, 0, 0, 8], [0, 0, 5, 1, 8, 3, 7, 0, 0]]
# [[0, 0, 3, 6, 0, 0, 0, 1, 0], [9, 1, 4, 0, 0, 0, 0, 0, 6], [6, 0, 0, 5, 0, 4, 0, 9, 3], [0, 4, 2, 0, 3, 8, 9, 0, 0], [0, 0, 7, 0, 0, 0, 5, 0, 0], [0, 0, 5, 9, 7, 0, 4, 2, 0], [8, 7, 0, 3, 0, 6, 0, 0, 5], [2, 0, 0, 0, 0, 0, 1, 8, 3], [0, 4, 0, 0, 0, 8, 7, 0, 0]]

# %%
# current_grid = fillrandom(blocks)
# print(current_grid)
# newgrid = flip(current_grid , flag)
# print(newgrid)

# %%
current_grid = fillrandom(blocks)
temperature = 1
cooling_rate = 0.95
iteration = 200
stuck_count = 0
loop_count = 0
while True:
    for i in range (iteration):
        stuck_count += 1
        loop_count += 1
        newgrid = flip(current_grid, flag)
        if fitness(newgrid) < fitness(current_grid):
            current_grid = newgrid
            print("Accepted better solution")
        else:
            acceptance_probability = np.exp((fitness(current_grid) - fitness(newgrid)) / temperature)
            if random.random() < acceptance_probability:
                current_grid = newgrid
                print("Accepted worse solution")

        if fitness(current_grid) == 0:
            print("Solution found")
            print(f"Total loops: {loop_count}")
            print(current_grid)
            break
        print(fitness(current_grid),stuck_count,loop_count)
    temperature = temperature * cooling_rate 
    print(f"End of iteration, temperature: {temperature}")
    if stuck_count == 30000:
        current_grid = fillrandom(blocks)
        stuck_count = 0
        print("Restarting with new random grid")
        temperature = temperature + 2
    
    if fitness(current_grid) == 0:
        break
# Out:
# 40 1 1
# Accepted better solution
# 39 2 2
# Accepted worse solution
# 39 3 3
# Accepted better solution
# 37 4 4
# 37 5 5
# 37 6 6
# Accepted better solution
# 35 7 7
# Accepted better solution
# 34 8 8
# 34 9 9
# 34 10 10
# 34 11 11
# 34 12 12
# 34 13 13
# Accepted better solution
# 32 14 14
# 32 15 15
# 32 16 16
# Accepted worse solution
# 33 17 17
# Accepted worse solution
# 33 18 18
# Accepted worse solution
# 34 19 19
# Accepted worse solution
# 35 20 20
# Accepted worse solution
# 35 21 21
# 35 22 22
# Accepted better solution
# 34 23 23
# 34 24 24
# Accepted worse solution
# 34 25 25
# Accepted worse solution
# 34 26 26
# 34 27 27
# 34 28 28
# Accepted better solution
# 33 29 29
# 33 30 30
# 33 31 31
# 33 32 32
# Accepted worse solution
# 33 33 33
# Accepted worse solution
# 33 34 34
# Accepted better solution
# 32 35 35
# Accepted worse solution
# 33 36 36
# 33 37 37
# 33 38 38
# 33 39 39
# Accepted worse solution
# 35 40 40
# Accepted better solution
# 32 41 41
# Accepted better solution
# 31 42 42
# 31 43 43
# Accepted worse solution
# 31 44 44
# 31 45 45
# 31 46 46
# 31 47 47
# Accepted better solution
# 28 48 48
# Accepted worse solution
# 29 49 49
# Accepted better solution
# 27 50 50
# Accepted better solution
# 25 51 51
# Accepted worse solution
# 26 52 52
# Accepted better solution
# 24 53 53
# 24 54 54
# 24 55 55
# 24 56 56
# Accepted worse solution
# 24 57 57
# Accepted worse solution
# 24 58 58
# 24 59 59
# 24 60 60
# Accepted worse solution
# 25 61 61
# Accepted worse solution
# 26 62 62
# 26 63 63
# 26 64 64
# 26 65 65
# 26 66 66
# Accepted worse solution
# 27 67 67
# 27 68 68
# Accepted worse solution
# 28 69 69
# 28 70 70
# Accepted worse solution
# 28 71 71
# 28 72 72
# Accepted better solution
# 26 73 73
# 26 74 74
# 26 75 75
# 26 76 76
# 26 77 77
# 26 78 78
# 26 79 79
# 26 80 80
# 26 81 81
# 26 82 82
# Accepted worse solution
# 27 83 83
# Accepted worse solution
# 27 84 84
# 27 85 85
# 27 86 86
# Accepted better solution
# 26 87 87
# Accepted better solution
# 24 88 88
# Accepted worse solution
# 24 89 89
# 24 90 90
# Accepted worse solution
# 24 91 91
# Accepted better solution
# 22 92 92
# 22 93 93
# 22 94 94
# Accepted better solution
# 21 95 95
# Accepted worse solution
# 23 96 96
# Accepted worse solution
# 23 97 97
# Accepted worse solution
# 25 98 98
# 25 99 99
# 25 100 100
# 25 101 101
# Accepted worse solution
# 26 102 102
# 26 103 103
# 26 104 104
# Accepted worse solution
# 26 105 105
# Accepted worse solution
# 27 106 106
# Accepted worse solution
# 27 107 107
# Accepted better solution
# 26 108 108
# Accepted better solution
# 25 109 109
# Accepted worse solution
# 26 110 110
# 26 111 111
# Accepted worse solution
# 26 112 112
# 26 113 113
# 26 114 114
# 26 115 115
# 26 116 116
# 26 117 117
# Accepted worse solution
# 27 118 118
# 27 119 119
# Accepted worse solution
# 28 120 120
# 28 121 121
# 28 122 122
# Accepted worse solution
# 28 123 123
# 28 124 124
# Accepted better solution
# 27 125 125
# 27 126 126
# Accepted better solution
# 26 127 127
# Accepted worse solution
# 26 128 128
# Accepted worse solution
# 27 129 129
# 27 130 130
# Accepted worse solution
# 27 131 131
# 27 132 132
# Accepted worse solution
# 27 133 133
# 27 134 134
# Accepted worse solution
# 27 135 135
# 27 136 136
# Accepted better solution
# 26 137 137
# Accepted worse solution
# 28 138 138
# 28 139 139
# Accepted worse solution
# 29 140 140
# Accepted better solution
# 28 141 141
# Accepted better solution
# 27 142 142
# 27 143 143
# Accepted worse solution
# 28 144 144
# 28 145 145
# 28 146 146
# Accepted worse solution
# 28 147 147
# Accepted worse solution
# 28 148 148
# Accepted better solution
# 26 149 149
# 26 150 150
# Accepted better solution
# 25 151 151
# 25 152 152
# Accepted worse solution
# 25 153 153
# Accepted better solution
# 24 154 154
# 24 155 155
# Accepted better solution
# 23 156 156
# 23 157 157
# Accepted worse solution
# 24 158 158
# 24 159 159
# Accepted worse solution
# 24 160 160
# Accepted better solution
# 23 161 161
# Accepted worse solution
# 24 162 162
# Accepted worse solution
# 24 163 163
# 24 164 164
# 24 165 165
# Accepted better solution
# 22 166 166
# 22 167 167
# Accepted worse solution
# 23 168 168
# 23 169 169
# 23 170 170
# 23 171 171
# Accepted worse solution
# 25 172 172
# Accepted worse solution
# 25 173 173
# 25 174 174
# Accepted worse solution
# 25 175 175
# 25 176 176
# Accepted better solution
# 23 177 177
# 23 178 178
# Accepted better solution
# 21 179 179
# 21 180 180
# 21 181 181
# 21 182 182
# 21 183 183
# Accepted worse solution
# 21 184 184
# 21 185 185
# 21 186 186
# Accepted worse solution
# 21 187 187
# 21 188 188
# Accepted worse solution
# 21 189 189
# Accepted better solution
# 20 190 190
# Accepted better solution
# 18 191 191
# Accepted worse solution
# 18 192 192
# 18 193 193
# 18 194 194
# 18 195 195
# 18 196 196
# 18 197 197
# Accepted worse solution
# 19 198 198
# 19 199 199
# 19 200 200
# End of iteration, temperature: 0.95
# 19 201 201
# 19 202 202
# Accepted worse solution
# 19 203 203
# 19 204 204
# Accepted better solution
# 18 205 205
# 18 206 206
# Accepted worse solution
# 19 207 207
# Accepted worse solution
# 19 208 208
# Accepted worse solution
# 19 209 209
# 19 210 210
# Accepted worse solution
# 21 211 211
# Accepted worse solution
# 21 212 212
# 21 213 213
# 21 214 214
# 21 215 215
# Accepted better solution
# 20 216 216
# 20 217 217
# 20 218 218
# Accepted worse solution
# 21 219 219
# 21 220 220
# 21 221 221
# Accepted worse solution
# 21 222 222
# 21 223 223
# 21 224 224
# 21 225 225
# 21 226 226
# 21 227 227
# 21 228 228
# Accepted better solution
# 20 229 229
# Accepted worse solution
# 20 230 230
# Accepted worse solution
# 21 231 231
# Accepted worse solution
# 22 232 232
# 22 233 233
# Accepted worse solution
# 23 234 234
# Accepted better solution
# 21 235 235
# 21 236 236
# 21 237 237
# 21 238 238
# 21 239 239
# Accepted worse solution
# 21 240 240
# 21 241 241
# 21 242 242
# Accepted worse solution
# 21 243 243
# 21 244 244
# Accepted better solution
# 19 245 245
# Accepted worse solution
# 20 246 246
# 20 247 247
# Accepted better solution
# 19 248 248
# Accepted worse solution
# 21 249 249
# Accepted worse solution
# 23 250 250
# Accepted better solution
# 22 251 251
# Accepted better solution
# 20 252 252
# 20 253 253
# 20 254 254
# 20 255 255
# 20 256 256
# Accepted better solution
# 19 257 257
# Accepted worse solution
# 19 258 258
# Accepted better solution
# 17 259 259
# 17 260 260
# 17 261 261
# Accepted better solution
# 15 262 262
# 15 263 263
# 15 264 264
# Accepted worse solution
# 15 265 265
# 15 266 266
# Accepted worse solution
# 15 267 267
# Accepted worse solution
# 16 268 268
# Accepted worse solution
# 17 269 269
# 17 270 270
# Accepted worse solution
# 19 271 271
# 19 272 272
# 19 273 273
# Accepted worse solution
# 21 274 274
# Accepted worse solution
# 21 275 275
# 21 276 276
# Accepted worse solution
# 23 277 277
# 23 278 278
# 23 279 279
# 23 280 280
# 23 281 281
# Accepted worse solution
# 23 282 282
# Accepted worse solution
# 23 283 283
# 23 284 284
# 23 285 285
# Accepted worse solution
# 23 286 286
# 23 287 287
# Accepted worse solution
# 23 288 288
# 23 289 289
# 23 290 290
# Accepted worse solution
# 23 291 291
# Accepted better solution
# 22 292 292
# 22 293 293
# 22 294 294
# 22 295 295
# 22 296 296
# 22 297 297
# 22 298 298
# 22 299 299
# Accepted better solution
# 20 300 300
# 20 301 301
# 20 302 302
# 20 303 303
# 20 304 304
# 20 305 305
# 20 306 306
# 20 307 307
# 20 308 308
# Accepted worse solution
# 20 309 309
# Accepted better solution
# 18 310 310
# 18 311 311
# 18 312 312
# Accepted worse solution
# 18 313 313
# 18 314 314
# 18 315 315
# 18 316 316
# 18 317 317
# Accepted worse solution
# 18 318 318
# 18 319 319
# Accepted better solution
# 17 320 320
# 17 321 321
# 17 322 322
# 17 323 323
# 17 324 324
# 17 325 325
# 17 326 326
# Accepted worse solution
# 17 327 327
# 17 328 328
# 17 329 329
# Accepted worse solution
# 19 330 330
# Accepted worse solution
# 19 331 331
# Accepted worse solution
# 19 332 332
# 19 333 333
# 19 334 334
# 19 335 335
# Accepted worse solution
# 20 336 336
# Accepted better solution
# 16 337 337
# 16 338 338
# Accepted better solution
# 14 339 339
# 14 340 340
# Accepted worse solution
# 15 341 341
# 15 342 342
# Accepted worse solution
# 19 343 343
# Accepted worse solution
# 19 344 344
# Accepted worse solution
# 19 345 345
# Accepted better solution
# 18 346 346
# 18 347 347
# 18 348 348
# 18 349 349
# Accepted worse solution
# 21 350 350
# 21 351 351
# 21 352 352
# 21 353 353
# 21 354 354
# Accepted better solution
# 20 355 355
# 20 356 356
# 20 357 357
# 20 358 358
# 20 359 359
# 20 360 360
# Accepted worse solution
# 20 361 361
# Accepted worse solution
# 22 362 362
# Accepted worse solution
# 23 363 363
# Accepted better solution
# 22 364 364
# 22 365 365
# 22 366 366
# Accepted worse solution
# 23 367 367
# 23 368 368
# Accepted better solution
# 22 369 369
# 22 370 370
# Accepted worse solution
# 23 371 371
# Accepted worse solution
# 25 372 372
# Accepted worse solution
# 26 373 373
# 26 374 374
# Accepted worse solution
# 27 375 375
# Accepted worse solution
# 27 376 376
# Accepted better solution
# 26 377 377
# Accepted better solution
# 24 378 378
# Accepted better solution
# 23 379 379
# Accepted worse solution
# 23 380 380
# 23 381 381
# 23 382 382
# Accepted worse solution
# 26 383 383
# Accepted better solution
# 25 384 384
# 25 385 385
# 25 386 386
# Accepted better solution
# 24 387 387
# 24 388 388
# 24 389 389
# 24 390 390
# 24 391 391
# 24 392 392
# 24 393 393
# Accepted worse solution
# 24 394 394
# Accepted worse solution
# 25 395 395
# 25 396 396
# 25 397 397
# 25 398 398
# Accepted better solution
# 24 399 399
# 24 400 400
# End of iteration, temperature: 0.9025
# Accepted better solution
# 22 401 401
# 22 402 402
# 22 403 403
# 22 404 404
# Accepted better solution
# 21 405 405
# 21 406 406
# 21 407 407
# 21 408 408
# Accepted worse solution
# 21 409 409
# 21 410 410
# 21 411 411
# 21 412 412
# 21 413 413
# Accepted worse solution
# 21 414 414
# 21 415 415
# Accepted worse solution
# 22 416 416
# 22 417 417
# 22 418 418
# 22 419 419
# Accepted better solution
# 21 420 420
# 21 421 421
# Accepted better solution
# 20 422 422
# 20 423 423
# 20 424 424
# Accepted worse solution
# 20 425 425
# Accepted worse solution
# 20 426 426
# Accepted better solution
# 19 427 427
# 19 428 428
# 19 429 429
# 19 430 430
# 19 431 431
# Accepted worse solution
# 20 432 432
# 20 433 433
# 20 434 434
# Accepted worse solution
# 20 435 435
# Accepted better solution
# 18 436 436
# Accepted worse solution
# 20 437 437
# 20 438 438
# 20 439 439
# 20 440 440
# Accepted better solution
# 18 441 441
# 18 442 442
# Accepted worse solution
# 18 443 443
# 18 444 444
# Accepted worse solution
# 19 445 445
# 19 446 446
# Accepted worse solution
# 19 447 447
# 19 448 448
# Accepted worse solution
# 20 449 449
# 20 450 450
# Accepted worse solution
# 20 451 451
# 20 452 452
# 20 453 453
# 20 454 454
# Accepted worse solution
# 20 455 455
# 20 456 456
# 20 457 457
# Accepted better solution
# 19 458 458
# 19 459 459
# 19 460 460
# 19 461 461
# 19 462 462
# 19 463 463
# 19 464 464
# 19 465 465
# Accepted worse solution
# 20 466 466
# 20 467 467
# 20 468 468
# 20 469 469
# 20 470 470
# 20 471 471
# Accepted worse solution
# 20 472 472
# 20 473 473
# 20 474 474
# Accepted worse solution
# 20 475 475
# Accepted worse solution
# 20 476 476
# Accepted worse solution
# 20 477 477
# 20 478 478
# 20 479 479
# 20 480 480
# 20 481 481
# 20 482 482
# 20 483 483
# 20 484 484
# Accepted worse solution
# 21 485 485
# Accepted worse solution
# 21 486 486
# Accepted worse solution
# 21 487 487
# Accepted better solution
# 19 488 488
# 19 489 489
# 19 490 490
# Accepted worse solution
# 19 491 491
# Accepted worse solution
# 19 492 492
# 19 493 493
# 19 494 494
# Accepted better solution
# 18 495 495
# 18 496 496
# 18 497 497
# 18 498 498
# 18 499 499
# 18 500 500
# 18 501 501
# 18 502 502
# 18 503 503
# 18 504 504
# 18 505 505
# 18 506 506
# 18 507 507
# 18 508 508
# Accepted worse solution
# 18 509 509
# Accepted better solution
# 16 510 510
# Accepted better solution
# 15 511 511
# Accepted worse solution
# 15 512 512
# 15 513 513
# Accepted worse solution
# 15 514 514
# 15 515 515
# 15 516 516
# 15 517 517
# 15 518 518
# 15 519 519
# 15 520 520
# 15 521 521
# 15 522 522
# Accepted worse solution
# 15 523 523
# 15 524 524
# 15 525 525
# Accepted worse solution
# 16 526 526
# Accepted better solution
# 15 527 527
# Accepted worse solution
# 15 528 528
# 15 529 529
# 15 530 530
# 15 531 531
# Accepted worse solution
# 16 532 532
# Accepted better solution
# 15 533 533
# 15 534 534
# 15 535 535
# 15 536 536
# Accepted worse solution
# 16 537 537
# 16 538 538
# 16 539 539
# 16 540 540
# Accepted worse solution
# 18 541 541
# Accepted worse solution
# 18 542 542
# 18 543 543
# 18 544 544
# 18 545 545
# Accepted worse solution
# 18 546 546
# Accepted worse solution
# 18 547 547
# 18 548 548
# 18 549 549
# 18 550 550
# Accepted worse solution
# 18 551 551
# Accepted worse solution
# 18 552 552
# 18 553 553
# Accepted better solution
# 16 554 554
# 16 555 555
# 16 556 556
# Accepted worse solution
# 17 557 557
# 17 558 558
# 17 559 559
# 17 560 560
# 17 561 561
# Accepted better solution
# 16 562 562
# Accepted better solution
# 15 563 563
# 15 564 564
# 15 565 565
# 15 566 566
# Accepted worse solution
# 17 567 567
# 17 568 568
# Accepted worse solution
# 17 569 569
# 17 570 570
# Accepted worse solution
# 19 571 571
# 19 572 572
# 19 573 573
# 19 574 574
# Accepted worse solution
# 21 575 575
# 21 576 576
# 21 577 577
# 21 578 578
# 21 579 579
# 21 580 580
# 21 581 581
# 21 582 582
# Accepted worse solution
# 22 583 583
# 22 584 584
# 22 585 585
# Accepted worse solution
# 22 586 586
# Accepted worse solution
# 22 587 587
# 22 588 588
# Accepted worse solution
# 23 589 589
# 23 590 590
# Accepted worse solution
# 24 591 591
# Accepted worse solution
# 24 592 592
# Accepted better solution
# 23 593 593
# Accepted worse solution
# 23 594 594
# 23 595 595
# 23 596 596
# Accepted worse solution
# 23 597 597
# 23 598 598
# Accepted worse solution
# 23 599 599
# 23 600 600
# End of iteration, temperature: 0.8573749999999999
# 23 601 601
# 23 602 602
# Accepted worse solution
# 23 603 603
# 23 604 604
# Accepted worse solution
# 23 605 605
# Accepted worse solution
# 23 606 606
# Accepted worse solution
# 24 607 607
# 24 608 608
# 24 609 609
# 24 610 610
# 24 611 611
# 24 612 612
# Accepted worse solution
# 24 613 613
# Accepted better solution
# 23 614 614
# 23 615 615
# Accepted worse solution
# 23 616 616
# 23 617 617
# 23 618 618
# Accepted worse solution
# 24 619 619
# 24 620 620
# Accepted worse solution
# 25 621 621
# 25 622 622
# Accepted worse solution
# 26 623 623
# Accepted better solution
# 24 624 624
# Accepted worse solution
# 24 625 625
# Accepted worse solution
# 24 626 626
# Accepted better solution
# 23 627 627
# Accepted worse solution
# 23 628 628
# 23 629 629
# 23 630 630
# Accepted better solution
# 21 631 631
# 21 632 632
# Accepted worse solution
# 21 633 633
# Accepted worse solution
# 22 634 634
# 22 635 635
# Accepted worse solution
# 22 636 636
# 22 637 637
# Accepted worse solution
# 23 638 638
# 23 639 639
# 23 640 640
# Accepted worse solution
# 24 641 641
# 24 642 642
# 24 643 643
# Accepted better solution
# 23 644 644
# 23 645 645
# 23 646 646
# 23 647 647
# 23 648 648
# 23 649 649
# Accepted better solution
# 21 650 650
# 21 651 651
# Accepted worse solution
# 22 652 652
# Accepted better solution
# 21 653 653
# Accepted worse solution
# 21 654 654
# Accepted worse solution
# 21 655 655
# 21 656 656
# 21 657 657
# Accepted worse solution
# 22 658 658
# Accepted better solution
# 21 659 659
# Accepted worse solution
# 21 660 660
# Accepted worse solution
# 21 661 661
# Accepted worse solution
# 21 662 662
# 21 663 663
# 21 664 664
# 21 665 665
# Accepted worse solution
# 23 666 666
# 23 667 667
# Accepted worse solution
# 24 668 668
# 24 669 669
# Accepted worse solution
# 25 670 670
# 25 671 671
# 25 672 672
# 25 673 673
# 25 674 674
# 25 675 675
# 25 676 676
# 25 677 677
# 25 678 678
# Accepted worse solution
# 25 679 679
# 25 680 680
# 25 681 681
# Accepted better solution
# 24 682 682
# 24 683 683
# 24 684 684
# 24 685 685
# Accepted better solution
# 22 686 686
# 22 687 687
# 22 688 688
# 22 689 689
# 22 690 690
# 22 691 691
# 22 692 692
# 22 693 693
# 22 694 694
# Accepted worse solution
# 23 695 695
# 23 696 696
# 23 697 697
# 23 698 698
# 23 699 699
# Accepted worse solution
# 24 700 700
# Accepted worse solution
# 24 701 701
# Accepted worse solution
# 24 702 702
# Accepted better solution
# 23 703 703
# 23 704 704
# 23 705 705
# 23 706 706
# 23 707 707
# Accepted worse solution
# 25 708 708
# 25 709 709
# 25 710 710
# 25 711 711
# Accepted worse solution
# 25 712 712
# 25 713 713
# 25 714 714
# 25 715 715
# Accepted better solution
# 24 716 716
# 24 717 717
# 24 718 718
# 24 719 719
# 24 720 720
# 24 721 721
# 24 722 722
# Accepted better solution
# 23 723 723
# Accepted better solution
# 21 724 724
# 21 725 725
# 21 726 726
# Accepted worse solution
# 21 727 727
# 21 728 728
# 21 729 729
# 21 730 730
# 21 731 731
# 21 732 732
# 21 733 733
# 21 734 734
# 21 735 735
# 21 736 736
# 21 737 737
# Accepted worse solution
# 22 738 738
# Accepted worse solution
# 23 739 739
# Accepted better solution
# 19 740 740
# 19 741 741
# 19 742 742
# 19 743 743
# 19 744 744
# 19 745 745
# Accepted worse solution
# 19 746 746
# 19 747 747
# 19 748 748
# 19 749 749
# 19 750 750
# 19 751 751
# 19 752 752
# Accepted worse solution
# 19 753 753
# 19 754 754
# 19 755 755
# 19 756 756
# 19 757 757
# 19 758 758
# 19 759 759
# 19 760 760
# Accepted worse solution
# 21 761 761
# Accepted worse solution
# 22 762 762
# 22 763 763
# Accepted worse solution
# 22 764 764
# 22 765 765
# Accepted worse solution
# 22 766 766
# 22 767 767
# 22 768 768
# 22 769 769
# 22 770 770
# 22 771 771
# Accepted worse solution
# 22 772 772
# Accepted better solution
# 21 773 773
# Accepted worse solution
# 21 774 774
# Accepted better solution
# 20 775 775
# Accepted worse solution
# 20 776 776
# Accepted worse solution
# 21 777 777
# 21 778 778
# 21 779 779
# 21 780 780
# Accepted worse solution
# 21 781 781
# 21 782 782
# 21 783 783
# Accepted worse solution
# 23 784 784
# 23 785 785
# Accepted better solution
# 21 786 786
# Accepted worse solution
# 22 787 787
# 22 788 788
# 22 789 789
# 22 790 790
# 22 791 791
# Accepted worse solution
# 22 792 792
# 22 793 793
# Accepted better solution
# 21 794 794
# 21 795 795
# 21 796 796
# 21 797 797
# 21 798 798
# Accepted better solution
# 20 799 799
# 20 800 800
# End of iteration, temperature: 0.8145062499999999
# 20 801 801
# Accepted better solution
# 19 802 802
# 19 803 803
# 19 804 804
# Accepted worse solution
# 20 805 805
# 20 806 806
# Accepted worse solution
# 20 807 807
# 20 808 808
# Accepted worse solution
# 20 809 809
# 20 810 810
# 20 811 811
# Accepted better solution
# 18 812 812
# 18 813 813
# 18 814 814
# Accepted worse solution
# 18 815 815
# 18 816 816
# Accepted worse solution
# 18 817 817
# 18 818 818
# Accepted worse solution
# 18 819 819
# 18 820 820
# 18 821 821
# Accepted better solution
# 16 822 822
# 16 823 823
# 16 824 824
# 16 825 825
# 16 826 826
# 16 827 827
# 16 828 828
# 16 829 829
# Accepted worse solution
# 16 830 830
# Accepted worse solution
# 18 831 831
# 18 832 832
# 18 833 833
# 18 834 834
# 18 835 835
# 18 836 836
# 18 837 837
# Accepted worse solution
# 19 838 838
# 19 839 839
# 19 840 840
# 19 841 841
# 19 842 842
# 19 843 843
# 19 844 844
# 19 845 845
# Accepted worse solution
# 20 846 846
# 20 847 847
# Accepted better solution
# 18 848 848
# 18 849 849
# Accepted worse solution
# 18 850 850
# 18 851 851
# 18 852 852
# Accepted worse solution
# 18 853 853
# Accepted worse solution
# 18 854 854
# 18 855 855
# 18 856 856
# 18 857 857
# 18 858 858
# Accepted worse solution
# 18 859 859
# 18 860 860
# 18 861 861
# Accepted worse solution
# 19 862 862
# 19 863 863
# 19 864 864
# 19 865 865
# 19 866 866
# Accepted better solution
# 18 867 867
# 18 868 868
# 18 869 869
# 18 870 870
# 18 871 871
# Accepted worse solution
# 19 872 872
# Accepted better solution
# 17 873 873
# Accepted worse solution
# 18 874 874
# 18 875 875
# Accepted worse solution
# 19 876 876
# 19 877 877
# Accepted worse solution
# 20 878 878
# 20 879 879
# Accepted better solution
# 19 880 880
# Accepted better solution
# 17 881 881
# 17 882 882
# 17 883 883
# Accepted worse solution
# 17 884 884
# 17 885 885
# 17 886 886
# Accepted worse solution
# 18 887 887
# 18 888 888
# Accepted better solution
# 17 889 889
# Accepted worse solution
# 19 890 890
# Accepted worse solution
# 19 891 891
# 19 892 892
# 19 893 893
# 19 894 894
# 19 895 895
# Accepted better solution
# 18 896 896
# 18 897 897
# 18 898 898
# Accepted worse solution
# 19 899 899
# 19 900 900
# 19 901 901
# 19 902 902
# 19 903 903
# 19 904 904
# 19 905 905
# 19 906 906
# 19 907 907
# 19 908 908
# 19 909 909
# 19 910 910
# Accepted worse solution
# 19 911 911
# Accepted worse solution
# 19 912 912
# Accepted worse solution
# 19 913 913
# 19 914 914
# 19 915 915
# 19 916 916
# 19 917 917
# Accepted worse solution
# 19 918 918
# 19 919 919
# 19 920 920
# Accepted worse solution
# 19 921 921
# Accepted worse solution
# 19 922 922
# Accepted worse solution
# 19 923 923
# Accepted worse solution
# 19 924 924
# Accepted worse solution
# 19 925 925
# 19 926 926
# Accepted worse solution
# 19 927 927
# 19 928 928
# 19 929 929
# 19 930 930
# 19 931 931
# Accepted better solution
# 17 932 932
# 17 933 933
# Accepted worse solution
# 17 934 934
# 17 935 935
# Accepted worse solution
# 17 936 936
# 17 937 937
# 17 938 938
# 17 939 939
# 17 940 940
# 17 941 941
# 17 942 942
# Accepted better solution
# 15 943 943
# 15 944 944
# 15 945 945
# 15 946 946
# Accepted worse solution
# 15 947 947
# 15 948 948
# 15 949 949
# 15 950 950
# 15 951 951
# 15 952 952
# 15 953 953
# 15 954 954
# Accepted worse solution
# 15 955 955
# 15 956 956
# 15 957 957
# 15 958 958
# 15 959 959
# 15 960 960
# 15 961 961
# 15 962 962
# 15 963 963
# 15 964 964
# Accepted worse solution
# 16 965 965
# 16 966 966
# 16 967 967
# Accepted better solution
# 15 968 968
# 15 969 969
# 15 970 970
# Accepted better solution
# 13 971 971
# Accepted better solution
# 12 972 972
# Accepted better solution
# 11 973 973
# 11 974 974
# Accepted worse solution
# 12 975 975
# Accepted worse solution
# 14 976 976
# 14 977 977
# 14 978 978
# 14 979 979
# 14 980 980
# 14 981 981
# Accepted worse solution
# 14 982 982
# 14 983 983
# Accepted worse solution
# 16 984 984
# 16 985 985
# 16 986 986
# Accepted worse solution
# 16 987 987
# 16 988 988
# 16 989 989
# Accepted worse solution
# 17 990 990
# 17 991 991
# Accepted better solution
# 16 992 992
# Accepted worse solution
# 16 993 993
# 16 994 994
# 16 995 995
# 16 996 996
# 16 997 997
# 16 998 998
# 16 999 999
# 16 1000 1000
# End of iteration, temperature: 0.7737809374999999
# 16 1001 1001
# 16 1002 1002
# Accepted better solution
# 14 1003 1003
# 14 1004 1004
# 14 1005 1005
# Accepted worse solution
# 15 1006 1006
# Accepted worse solution
# 15 1007 1007
# Accepted worse solution
# 17 1008 1008
# 17 1009 1009
# Accepted worse solution
# 18 1010 1010
# 18 1011 1011
# 18 1012 1012
# Accepted worse solution
# 19 1013 1013
# Accepted worse solution
# 19 1014 1014
# 19 1015 1015
# 19 1016 1016
# 19 1017 1017
# 19 1018 1018
# Accepted worse solution
# 19 1019 1019
# 19 1020 1020
# 19 1021 1021
# 19 1022 1022
# 19 1023 1023
# 19 1024 1024
# 19 1025 1025
# Accepted worse solution
# 20 1026 1026
# Accepted worse solution
# 20 1027 1027
# Accepted better solution
# 19 1028 1028
# 19 1029 1029
# 19 1030 1030
# 19 1031 1031
# Accepted worse solution
# 19 1032 1032
# 19 1033 1033
# Accepted better solution
# 18 1034 1034
# 18 1035 1035
# 18 1036 1036
# 18 1037 1037
# Accepted better solution
# 17 1038 1038
# 17 1039 1039
# 17 1040 1040
# 17 1041 1041
# Accepted worse solution
# 17 1042 1042
# 17 1043 1043
# 17 1044 1044
# Accepted better solution
# 15 1045 1045
# 15 1046 1046
# Accepted worse solution
# 16 1047 1047
# Accepted better solution
# 15 1048 1048
# 15 1049 1049
# Accepted worse solution
# 17 1050 1050
# 17 1051 1051
# 17 1052 1052
# Accepted worse solution
# 17 1053 1053
# 17 1054 1054
# 17 1055 1055
# Accepted worse solution
# 17 1056 1056
# Accepted better solution
# 16 1057 1057
# 16 1058 1058
# 16 1059 1059
# 16 1060 1060
# 16 1061 1061
# 16 1062 1062
# 16 1063 1063
# Accepted worse solution
# 17 1064 1064
# 17 1065 1065
# 17 1066 1066
# 17 1067 1067
# 17 1068 1068
# 17 1069 1069
# 17 1070 1070
# Accepted worse solution
# 18 1071 1071
# 18 1072 1072
# 18 1073 1073
# 18 1074 1074
# 18 1075 1075
# 18 1076 1076
# 18 1077 1077
# 18 1078 1078
# Accepted worse solution
# 18 1079 1079
# 18 1080 1080
# Accepted better solution
# 16 1081 1081
# 16 1082 1082
# 16 1083 1083
# Accepted worse solution
# 16 1084 1084
# 16 1085 1085
# 16 1086 1086
# Accepted better solution
# 14 1087 1087
# Accepted worse solution
# 15 1088 1088
# 15 1089 1089
# 15 1090 1090
# 15 1091 1091
# 15 1092 1092
# 15 1093 1093
# 15 1094 1094
# 15 1095 1095
# 15 1096 1096
# 15 1097 1097
# 15 1098 1098
# 15 1099 1099
# Accepted worse solution
# 16 1100 1100
# 16 1101 1101
# 16 1102 1102
# Accepted better solution
# 15 1103 1103
# 15 1104 1104
# 15 1105 1105
# Accepted better solution
# 14 1106 1106
# 14 1107 1107
# 14 1108 1108
# 14 1109 1109
# 14 1110 1110
# 14 1111 1111
# 14 1112 1112
# 14 1113 1113
# 14 1114 1114
# 14 1115 1115
# 14 1116 1116
# 14 1117 1117
# 14 1118 1118
# 14 1119 1119
# 14 1120 1120
# 14 1121 1121
# 14 1122 1122
# 14 1123 1123
# Accepted worse solution
# 16 1124 1124
# 16 1125 1125
# 16 1126 1126
# 16 1127 1127
# 16 1128 1128
# Accepted worse solution
# 16 1129 1129
# 16 1130 1130
# 16 1131 1131
# 16 1132 1132
# 16 1133 1133
# Accepted worse solution
# 16 1134 1134
# Accepted worse solution
# 18 1135 1135
# 18 1136 1136
# Accepted worse solution
# 20 1137 1137
# 20 1138 1138
# 20 1139 1139
# 20 1140 1140
# 20 1141 1141
# 20 1142 1142
# Accepted better solution
# 18 1143 1143
# Accepted worse solution
# 18 1144 1144
# 18 1145 1145
# Accepted worse solution
# 18 1146 1146
# Accepted worse solution
# 18 1147 1147
# 18 1148 1148
# Accepted worse solution
# 18 1149 1149
# 18 1150 1150
# Accepted worse solution
# 18 1151 1151
# 18 1152 1152
# 18 1153 1153
# 18 1154 1154
# Accepted better solution
# 16 1155 1155
# 16 1156 1156
# 16 1157 1157
# 16 1158 1158
# 16 1159 1159
# 16 1160 1160
# 16 1161 1161
# 16 1162 1162
# 16 1163 1163
# Accepted better solution
# 14 1164 1164
# Accepted worse solution
# 15 1165 1165
# 15 1166 1166
# 15 1167 1167
# Accepted better solution
# 14 1168 1168
# 14 1169 1169
# 14 1170 1170
# 14 1171 1171
# 14 1172 1172
# 14 1173 1173
# 14 1174 1174
# 14 1175 1175
# 14 1176 1176
# Accepted better solution
# 13 1177 1177
# 13 1178 1178
# 13 1179 1179
# 13 1180 1180
# 13 1181 1181
# 13 1182 1182
# 13 1183 1183
# Accepted better solution
# 12 1184 1184
# 12 1185 1185
# 12 1186 1186
# 12 1187 1187
# 12 1188 1188
# Accepted worse solution
# 13 1189 1189
# Accepted better solution
# 12 1190 1190
# 12 1191 1191
# 12 1192 1192
# 12 1193 1193
# 12 1194 1194
# 12 1195 1195
# Accepted worse solution
# 12 1196 1196
# 12 1197 1197
# 12 1198 1198
# 12 1199 1199
# Accepted worse solution
# 12 1200 1200
# End of iteration, temperature: 0.7350918906249998
# 12 1201 1201
# 12 1202 1202
# 12 1203 1203
# 12 1204 1204
# 12 1205 1205
# 12 1206 1206
# 12 1207 1207
# 12 1208 1208
# 12 1209 1209
# 12 1210 1210
# 12 1211 1211
# 12 1212 1212
# 12 1213 1213
# 12 1214 1214
# 12 1215 1215
# 12 1216 1216
# Accepted worse solution
# 13 1217 1217
# 13 1218 1218
# 13 1219 1219
# 13 1220 1220
# Accepted better solution
# 12 1221 1221
# Accepted worse solution
# 13 1222 1222
# 13 1223 1223
# 13 1224 1224
# 13 1225 1225
# 13 1226 1226
# 13 1227 1227
# 13 1228 1228
# Accepted better solution
# 12 1229 1229
# 12 1230 1230
# 12 1231 1231
# 12 1232 1232
# 12 1233 1233
# 12 1234 1234
# 12 1235 1235
# 12 1236 1236
# 12 1237 1237
# 12 1238 1238
# 12 1239 1239
# 12 1240 1240
# 12 1241 1241
# Accepted worse solution
# 12 1242 1242
# 12 1243 1243
# 12 1244 1244
# 12 1245 1245
# 12 1246 1246
# Accepted better solution
# 11 1247 1247
# Accepted better solution
# 10 1248 1248
# Accepted better solution
# 8 1249 1249
# 8 1250 1250
# 8 1251 1251
# 8 1252 1252
# 8 1253 1253
# 8 1254 1254
# 8 1255 1255
# 8 1256 1256
# 8 1257 1257
# 8 1258 1258
# 8 1259 1259
# 8 1260 1260
# 8 1261 1261
# 8 1262 1262
# 8 1263 1263
# Accepted worse solution
# 8 1264 1264
# 8 1265 1265
# Accepted worse solution
# 10 1266 1266
# 10 1267 1267
# 10 1268 1268
# 10 1269 1269
# 10 1270 1270
# Accepted worse solution
# 10 1271 1271
# 10 1272 1272
# 10 1273 1273
# 10 1274 1274
# 10 1275 1275
# 10 1276 1276
# 10 1277 1277
# Accepted worse solution
# 10 1278 1278
# 10 1279 1279
# 10 1280 1280
# 10 1281 1281
# 10 1282 1282
# 10 1283 1283
# 10 1284 1284
# 10 1285 1285
# 10 1286 1286
# 10 1287 1287
# 10 1288 1288
# 10 1289 1289
# 10 1290 1290
# 10 1291 1291
# Accepted worse solution
# 10 1292 1292
# 10 1293 1293
# 10 1294 1294
# 10 1295 1295
# 10 1296 1296
# Accepted worse solution
# 10 1297 1297
# 10 1298 1298
# Accepted worse solution
# 10 1299 1299
# 10 1300 1300
# 10 1301 1301
# 10 1302 1302
# 10 1303 1303
# 10 1304 1304
# 10 1305 1305
# 10 1306 1306
# 10 1307 1307
# 10 1308 1308
# 10 1309 1309
# Accepted worse solution
# 11 1310 1310
# 11 1311 1311
# 11 1312 1312
# Accepted worse solution
# 12 1313 1313
# Accepted better solution
# 10 1314 1314
# 10 1315 1315
# 10 1316 1316
# Accepted worse solution
# 10 1317 1317
# Accepted worse solution
# 10 1318 1318
# 10 1319 1319
# 10 1320 1320
# Accepted better solution
# 9 1321 1321
# 9 1322 1322
# Accepted better solution
# 8 1323 1323
# 8 1324 1324
# 8 1325 1325
# 21 1453 1453
# Accepted worse solution
# 21 1454 1454
# 21 1455 1455
# 21 1456 1456
# 21 1457 1457
# 21 1458 1458
# 21 1459 1459
# 21 1460 1460
# 21 1461 1461
# 21 1462 1462
# 21 1463 1463
# 21 1464 1464
# 21 1465 1465
# Accepted worse solution
# 21 1466 1466
# 21 1467 1467
# 21 1468 1468
# Accepted worse solution
# 22 1469 1469
# Accepted worse solution
# 23 1470 1470
# Accepted worse solution
# 24 1471 1471
# 24 1472 1472
# 24 1473 1473
# 24 1474 1474
# Accepted worse solution
# 24 1475 1475
# Accepted better solution
# 23 1476 1476
# Accepted worse solution
# 24 1477 1477
# 24 1478 1478
# 24 1479 1479
# 24 1480 1480
# 24 1481 1481
# 24 1482 1482
# Accepted worse solution
# 26 1483 1483
# 26 1484 1484
# Accepted worse solution
# 26 1485 1485
# 26 1486 1486
# 26 1487 1487
# 26 1488 1488
# 26 1489 1489
# 26 1490 1490
# Accepted better solution
# 25 1491 1491
# 25 1492 1492
# Accepted worse solution
# 26 1493 1493
# 26 1494 1494
# 26 1495 1495
# Accepted worse solution
# 26 1496 1496
# Accepted worse solution
# 26 1497 1497
# Accepted worse solution
# 27 1498 1498
# 27 1499 1499
# 27 1500 1500
# 27 1501 1501
# Accepted worse solution
# 27 1502 1502
# 27 1503 1503
# Accepted better solution
# 26 1504 1504
# Accepted better solution
# 24 1505 1505
# 24 1506 1506
# Accepted better solution
# 23 1507 1507
# Accepted better solution
# 22 1508 1508
# Accepted better solution
# 21 1509 1509
# 21 1510 1510
# 21 1511 1511
# 21 1512 1512
# Accepted worse solution
# 21 1513 1513
# 21 1514 1514
# Accepted better solution
# 20 1515 1515
# Accepted worse solution
# 20 1516 1516
# 20 1517 1517
# Accepted worse solution
# 20 1518 1518
# Accepted worse solution
# 20 1519 1519
# 20 1520 1520
# Accepted worse solution
# 20 1521 1521
# Accepted worse solution
# 21 1522 1522
# Accepted worse solution
# 22 1523 1523
# 22 1524 1524
# 22 1525 1525
# Accepted worse solution
# 22 1526 1526
# 22 1527 1527
# 22 1528 1528
# 22 1529 1529
# 22 1530 1530
# 22 1531 1531
# 22 1532 1532
# Accepted better solution
# 20 1533 1533
# 20 1534 1534
# Accepted worse solution
# 20 1535 1535
# Accepted better solution
# 19 1536 1536
# 19 1537 1537
# 19 1538 1538
# 19 1539 1539
# Accepted better solution
# 18 1540 1540
# Accepted worse solution
# 19 1541 1541
# 19 1542 1542
# 19 1543 1543
# 19 1544 1544
# 19 1545 1545
# 19 1546 1546
# 19 1547 1547
# Accepted worse solution
# 19 1548 1548
# Accepted better solution
# 16 1549 1549
# Accepted worse solution
# 16 1550 1550
# 16 1551 1551
# 16 1552 1552
# 16 1553 1553
# Accepted worse solution
# 16 1554 1554
# 16 1555 1555
# 16 1556 1556
# 16 1557 1557
# 16 1558 1558
# 16 1559 1559
# 16 1560 1560
# Accepted better solution
# 15 1561 1561
# Accepted worse solution
# 15 1562 1562
# 15 1563 1563
# 15 1564 1564
# 15 1565 1565
# 15 1566 1566
# 15 1567 1567
# 15 1568 1568
# 15 1569 1569
# 15 1570 1570
# 15 1571 1571
# 15 1572 1572
# 15 1573 1573
# 15 1574 1574
# Accepted worse solution
# 17 1575 1575
# Accepted better solution
# 15 1576 1576
# Accepted better solution
# 14 1577 1577
# 14 1578 1578
# 14 1579 1579
# 14 1580 1580
# 14 1581 1581
# 14 1582 1582
# 14 1583 1583
# 14 1584 1584
# 14 1585 1585
# Accepted worse solution
# 14 1586 1586
# 14 1587 1587
# 14 1588 1588
# 14 1589 1589
# 14 1590 1590
# 14 1591 1591
# 14 1592 1592
# 14 1593 1593
# 14 1594 1594
# 14 1595 1595
# 14 1596 1596
# 14 1597 1597
# Accepted better solution
# 13 1598 1598
# 13 1599 1599
# 13 1600 1600
# End of iteration, temperature: 0.6634204312890623
# Accepted worse solution
# 14 1601 1601
# 14 1602 1602
# 14 1603 1603
# 14 1604 1604
# Accepted worse solution
# 16 1605 1605
# 16 1606 1606
# Accepted worse solution
# 17 1607 1607
# 17 1608 1608
# Accepted better solution
# 15 1609 1609
# 15 1610 1610
# 15 1611 1611
# 15 1612 1612
# 15 1613 1613
# 15 1614 1614
# 15 1615 1615
# 15 1616 1616
# 15 1617 1617
# 15 1618 1618
# Accepted worse solution
# 15 1619 1619
# 15 1620 1620
# 15 1621 1621
# 15 1622 1622
# 15 1623 1623
# 15 1624 1624
# 15 1625 1625
# 15 1626 1626
# 15 1627 1627
# Accepted worse solution
# 17 1628 1628
# 17 1629 1629
# Accepted worse solution
# 17 1630 1630
# 17 1631 1631
# 17 1632 1632
# 17 1633 1633
# 17 1634 1634
# 17 1635 1635
# 17 1636 1636
# Accepted worse solution
# 17 1637 1637
# Accepted worse solution
# 17 1638 1638
# Accepted worse solution
# 18 1639 1639
# 18 1640 1640
# Accepted worse solution
# 18 1641 1641
# 18 1642 1642
# 18 1643 1643
# 18 1644 1644
# 18 1645 1645
# Accepted better solution
# 16 1646 1646
# Accepted worse solution
# 17 1647 1647
# 17 1648 1648
# Accepted better solution
# 16 1649 1649
# 16 1650 1650
# 16 1651 1651
# Accepted worse solution
# 17 1652 1652
# 17 1653 1653
# 17 1654 1654
# 17 1655 1655
# 17 1656 1656
# 17 1657 1657
# 17 1658 1658
# 17 1659 1659
# 17 1660 1660
# 17 1661 1661
# 17 1662 1662
# 17 1663 1663
# 17 1664 1664
# 17 1665 1665
# Accepted better solution
# 16 1666 1666
# 16 1667 1667
# 16 1668 1668
# 16 1669 1669
# 16 1670 1670
# 16 1671 1671
# 16 1672 1672
# 16 1673 1673
# 16 1674 1674
# 16 1675 1675
# Accepted better solution
# 15 1676 1676
# 15 1677 1677
# 15 1678 1678
# 15 1679 1679
# 15 1680 1680
# Accepted worse solution
# 15 1681 1681
# 15 1682 1682
# 15 1683 1683
# Accepted worse solution
# 16 1684 1684
# 16 1685 1685
# 16 1686 1686
# 16 1687 1687
# 16 1688 1688
# 16 1689 1689
# 16 1690 1690
# 12 1823 1823
# 12 1824 1824
# 12 1825 1825
# 12 1826 1826
# Accepted worse solution
# 12 1827 1827
# 12 1828 1828
# 12 1829 1829
# 12 1830 1830
# 12 1831 1831
# 12 1832 1832
# 12 1833 1833
# Accepted better solution
# 11 1834 1834
# 11 1835 1835
# 11 1836 1836
# 11 1837 1837
# 11 1838 1838
# Accepted worse solution
# 12 1839 1839
# 12 1840 1840
# 12 1841 1841
# 12 1842 1842
# Accepted worse solution
# 12 1843 1843
# 12 1844 1844
# 12 1845 1845
# 12 1846 1846
# Accepted better solution
# 11 1847 1847
# 11 1848 1848
# 11 1849 1849
# 11 1850 1850
# 11 1851 1851
# 11 1852 1852
# 11 1853 1853
# 11 1854 1854
# 11 1855 1855
# Accepted worse solution
# 11 1856 1856
# 11 1857 1857
# 11 1858 1858
# Accepted worse solution
# 11 1859 1859
# 11 1860 1860
# 11 1861 1861
# 11 1862 1862
# 11 1863 1863
# Accepted worse solution
# 11 1864 1864
# 11 1865 1865
# 11 1866 1866
# 11 1867 1867
# 11 1868 1868
# 11 1869 1869
# 11 1870 1870
# 11 1871 1871
# 11 1872 1872
# 11 1873 1873
# 11 1874 1874
# 11 1875 1875
# 11 1876 1876
# 11 1877 1877
# 11 1878 1878
# 11 1879 1879
# 11 1880 1880
# 11 1881 1881
# 11 1882 1882
# 11 1883 1883
# 11 1884 1884
# 11 1885 1885
# 11 1886 1886
# Accepted worse solution
# 11 1887 1887
# 11 1888 1888
# 11 1889 1889
# Accepted worse solution
# 11 1890 1890
# 11 1891 1891
# 11 1892 1892
# Accepted worse solution
# 11 1893 1893
# 11 1894 1894
# Accepted worse solution
# 11 1895 1895
# 11 1896 1896
# 11 1897 1897
# 11 1898 1898
# 11 1899 1899
# 11 1900 1900
# 11 1901 1901
# 11 1902 1902
# Accepted worse solution
# 11 1903 1903
# 11 1904 1904
# 11 1905 1905
# 11 1906 1906
# 11 1907 1907
# 11 1908 1908
# Accepted better solution
# 10 1909 1909
# 10 1910 1910
# 10 1911 1911
# 10 1912 1912
# Accepted worse solution
# 11 1913 1913
# 11 1914 1914
# 11 1915 1915
# 11 1916 1916
# 11 1917 1917
# Accepted worse solution
# 12 1918 1918
# 12 1919 1919
# Accepted worse solution
# 12 1920 1920
# 12 1921 1921
# 12 1922 1922
# 12 1923 1923
# 12 1924 1924
# 12 1925 1925
# 12 1926 1926
# 12 1927 1927
# 12 1928 1928
# 12 1929 1929
# 12 1930 1930
# 12 1931 1931
# 12 1932 1932
# Accepted worse solution
# 12 1933 1933
# Accepted worse solution
# 12 1934 1934
# 12 1935 1935
# Accepted worse solution
# 12 1936 1936
# 12 1937 1937
# Accepted better solution
# 11 1938 1938
# Accepted better solution
# 10 1939 1939
# 10 1940 1940
# Accepted better solution
# 9 1941 1941
# 9 1942 1942
# 9 1943 1943
# Accepted worse solution
# 9 1944 1944
# 9 1945 1945
# 9 1946 1946
# 9 1947 1947
# 9 1948 1948
# 9 1949 1949
# Accepted better solution
# 9 2221 2221
# Accepted worse solution
# 9 2222 2222
# Accepted better solution
# 7 2223 2223
# Accepted worse solution
# 7 2224 2224
# 7 2225 2225
# 7 2226 2226
# 7 2227 2227
# 7 2228 2228
# Accepted worse solution
# 7 2229 2229
# 7 2230 2230
# 7 2231 2231
# Accepted better solution
# 6 2232 2232
# Accepted worse solution
# 7 2233 2233
# 7 2234 2234
# 7 2235 2235
# 7 2236 2236
# 7 2237 2237
# 7 2238 2238
# Accepted worse solution
# 7 2239 2239
# 7 2240 2240
# 7 2241 2241
# Accepted worse solution
# 7 2242 2242
# 7 2243 2243
# 7 2244 2244
# 7 2245 2245
# Accepted worse solution
# 8 2246 2246
# Accepted worse solution
# 8 2247 2247
# 8 2248 2248
# 8 2249 2249
# 8 2250 2250
# 8 2251 2251
# 8 2252 2252
# 8 2253 2253
# 8 2254 2254
# Accepted worse solution
# 10 2255 2255
# 10 2256 2256
# 10 2257 2257
# Accepted worse solution
# 10 2258 2258
# 10 2259 2259
# 10 2260 2260
# 10 2261 2261
# 10 2262 2262
# 10 2263 2263
# 10 2264 2264
# 10 2265 2265
# 10 2266 2266
# 10 2267 2267
# 10 2268 2268
# 10 2269 2269
# 10 2270 2270
# Accepted worse solution
# 11 2271 2271
# Accepted better solution
# 10 2272 2272
# 10 2273 2273
# 10 2274 2274
# 10 2275 2275
# 10 2276 2276
# 10 2277 2277
# 10 2278 2278
# 10 2279 2279
# 10 2280 2280
# 10 2281 2281
# 10 2282 2282
# 10 2283 2283
# 10 2284 2284
# 10 2285 2285
# 10 2286 2286
# 10 2287 2287
# 10 2288 2288
# 10 2289 2289
# 10 2290 2290
# 10 2291 2291
# 10 2292 2292
# 10 2293 2293
# 10 2294 2294
# 10 2295 2295
# 10 2296 2296
# 10 2297 2297
# 10 2298 2298
# 10 2299 2299
# 10 2300 2300
# 10 2301 2301
# 10 2302 2302
# 10 2303 2303
# 10 2304 2304
# 10 2305 2305
# 10 2306 2306
# 10 2307 2307
# Accepted worse solution
# 10 2308 2308
# Accepted better solution
# 9 2309 2309
# 9 2310 2310
# 9 2311 2311
# 9 2312 2312
# 9 2313 2313
# 9 2314 2314
# 9 2315 2315
# 9 2316 2316
# 9 2317 2317
# 9 2318 2318
# 9 2319 2319
# Accepted worse solution
# 9 2320 2320
# 9 2321 2321
# 9 2322 2322
# 9 2323 2323
# 9 2324 2324
# Accepted worse solution
# 11 2325 2325
# 11 2326 2326
# 11 2327 2327
# 11 2328 2328
# Accepted worse solution
# 13 2329 2329
# 13 2330 2330
# 13 2331 2331
# Accepted worse solution
# 13 2332 2332
# Accepted worse solution
# 15 2333 2333
# 15 2334 2334
# 15 2335 2335
# 15 2336 2336
# 15 2337 2337
# 15 2338 2338
# 15 2339 2339
# 15 2340 2340
# Accepted worse solution
# 15 2341 2341
# 15 2342 2342
# 15 2343 2343
# 15 2344 2344
# 15 2345 2345
# Accepted worse solution
# 15 2346 2346
# 15 2347 2347
# 15 2348 2348
# 15 2349 2349
# 15 2350 2350
# 15 2351 2351
# Accepted worse solution
# 15 2352 2352
# Accepted worse solution
# 15 2353 2353
# 15 2354 2354
# 15 2355 2355
# 15 2356 2356
# 15 2357 2357
# 15 2358 2358
# 15 2359 2359
# 15 2360 2360
# Accepted better solution
# 14 2361 2361
# 14 2362 2362
# 14 2363 2363
# 14 2364 2364
# Accepted worse solution
# 14 2365 2365
# 14 2366 2366
# 14 2367 2367
# 14 2368 2368
# 14 2369 2369
# Accepted worse solution
# 15 2370 2370
# 15 2371 2371
# 15 2372 2372
# 15 2373 2373
# Accepted worse solution
# 15 2374 2374
# 15 2375 2375
# 15 2376 2376
# 15 2377 2377
# 15 2378 2378
# 15 2379 2379
# Accepted worse solution
# 15 2380 2380
# 15 2381 2381
# Accepted worse solution
# 15 2382 2382
# 15 2383 2383
# 15 2384 2384
# 15 2385 2385
# 15 2386 2386
# 15 2387 2387
# 15 2388 2388
# Accepted better solution
# 14 2389 2389
# 14 2390 2390
# 14 2391 2391
# 14 2392 2392
# 14 2393 2393
# 14 2394 2394
# 14 2395 2395
# 14 2396 2396
# 14 2397 2397
# 14 2398 2398
# 14 2399 2399
# 14 2400 2400
# End of iteration, temperature: 0.5403600876626365
# Accepted better solution
# 13 2401 2401
# Accepted worse solution
# 13 2402 2402
# 13 2403 2403
# 13 2404 2404
# 13 2405 2405
# 13 2406 2406
# 13 2407 2407
# 13 2408 2408
# 13 2409 2409
# 13 2410 2410
# 13 2411 2411
# 13 2412 2412
# Accepted better solution
# 11 2413 2413
# 11 2414 2414
# Accepted worse solution
# 11 2415 2415
# 11 2416 2416
# Accepted worse solution
# 11 2417 2417
# 11 2418 2418
# 11 2419 2419
# Accepted better solution
# 9 2420 2420
# 9 2421 2421
# 9 2422 2422
# 9 2423 2423
# 9 2424 2424
# 9 2425 2425
# 9 2426 2426
# 9 2427 2427
# 9 2428 2428
# 9 2429 2429
# 9 2430 2430
# Accepted better solution
# 7 2431 2431
# 7 2432 2432
# 7 2433 2433
# 7 2434 2434
# 7 2435 2435
# 7 2436 2436
# 7 2437 2437
# 7 2438 2438
# 7 2439 2439
# 7 2440 2440
# 7 2441 2441
# 7 2442 2442
# 7 2443 2443
# 7 2444 2444
# 7 2445 2445
# 7 2446 2446
# 7 2447 2447
# 7 2448 2448
# Accepted worse solution
# 7 2449 2449
# 7 2450 2450
# 7 2451 2451
# 7 2452 2452
# 7 2453 2453
# 7 2454 2454
# 7 2455 2455
# 7 2456 2456
# 7 2457 2457
# 7 2458 2458
# 7 2459 2459
# 7 2460 2460
# 7 2461 2461
# 7 2462 2462
# 7 2463 2463
# 7 2464 2464
# 7 2465 2465
# 7 2466 2466
# 7 2467 2467
# 7 2468 2468
# Accepted worse solution
# 7 2469 2469
# 7 2470 2470
# 7 2471 2471
# 7 2472 2472
# 7 2473 2473
# 7 2474 2474
# 7 2475 2475
# 7 2476 2476
# 7 2477 2477
# 7 2478 2478
# 7 2479 2479
# Accepted better solution
# 6 2480 2480
# 8 2624 2624
# 8 2625 2625
# 8 2626 2626
# 8 2627 2627
# 8 2628 2628
# 8 2629 2629
# 8 2630 2630
# 8 2631 2631
# 8 2632 2632
# 8 2633 2633
# 8 2634 2634
# Accepted worse solution
# 8 2635 2635
# 8 2636 2636
# Accepted better solution
# 6 2637 2637
# 6 2638 2638
# 6 2639 2639
# 6 2640 2640
# Accepted worse solution
# 6 2641 2641
# 6 2642 2642
# 6 2643 2643
# 6 2644 2644
# 6 2645 2645
# 6 2646 2646
# Accepted worse solution
# 7 2647 2647
# 7 2648 2648
# 7 2649 2649
# 7 2650 2650
# 7 2651 2651
# 7 2652 2652
# 7 2653 2653
# Accepted worse solution
# 7 2654 2654
# 7 2655 2655
# Accepted worse solution
# 9 2656 2656
# 9 2657 2657
# 9 2658 2658
# 9 2659 2659
# 9 2660 2660
# 9 2661 2661
# 9 2662 2662
# 9 2663 2663
# 9 2664 2664
# 9 2665 2665
# 9 2666 2666
# 9 2667 2667
# 9 2668 2668
# 9 2669 2669
# 9 2670 2670
# 9 2671 2671
# 9 2672 2672
# 9 2673 2673
# 9 2674 2674
# 9 2675 2675
# 9 2676 2676
# 9 2677 2677
# 9 2678 2678
# 9 2679 2679
# 9 2680 2680
# 9 2681 2681
# 9 2682 2682
# Accepted better solution
# 8 2683 2683
# Accepted better solution
# 7 2684 2684
# 7 2685 2685
# Accepted worse solution
# 7 2686 2686
# 7 2687 2687
# 7 2688 2688
# 7 2689 2689
# 7 2690 2690
# 7 2691 2691
# 7 2692 2692
# 7 2693 2693
# 7 2694 2694
# 7 2695 2695
# 7 2696 2696
# Accepted worse solution
# 7 2697 2697
# 7 2698 2698
# 7 2699 2699
# 7 2700 2700
# 7 2701 2701
# 7 2702 2702
# 7 2703 2703
# 7 2704 2704
# 7 2705 2705
# 7 2706 2706
# 7 2707 2707
# 7 2708 2708
# 7 2709 2709
# 7 2710 2710
# 7 2711 2711
# 7 2712 2712
# 7 2713 2713
# Accepted worse solution
# 9 2714 2714
# 9 2715 2715
# 9 2716 2716
# 9 2717 2717
# 9 2718 2718
# 9 2719 2719
# 9 2720 2720
# 9 2721 2721
# 9 2722 2722
# 9 2723 2723
# Accepted worse solution
# 10 2724 2724
# 10 2725 2725
# 10 2726 2726
# 10 2727 2727
# Accepted better solution
# 9 2728 2728
# 9 2729 2729
# 9 2730 2730
# 9 2731 2731
# 9 2732 2732
# 9 2733 2733
# 9 2734 2734
# 9 2735 2735
# 9 2736 2736
# 9 2737 2737
# 9 2738 2738
# 9 2739 2739
# 9 2740 2740
# 9 2741 2741
# 9 2742 2742
# Accepted better solution
# 7 2743 2743
# 7 2744 2744
# 7 2745 2745
# 7 2746 2746
# 7 2747 2747
# 7 2748 2748
# 7 2749 2749
# 7 2750 2750
# 7 2751 2751
# 7 2752 2752
# Accepted better solution
# 5 2753 2753
# 5 2754 2754
# 5 2755 2755
# 5 2756 2756
# 5 2757 2757
# 5 2758 2758
# 5 2759 2759
# 5 2760 2760
# Accepted better solution
# 4 2761 2761
# 4 2762 2762
# 4 2763 2763
# Accepted worse solution
# 4 2764 2764
# 4 2765 2765
# 4 2766 2766
# 4 2767 2767
# 4 2768 2768
# 4 2769 2769
# 4 2770 2770
# Accepted worse solution
# 4 2771 2771
# 4 2772 2772
# 4 2773 2773
# 4 2774 2774
# 4 2775 2775
# 4 2776 2776
# 4 2777 2777
# 4 2778 2778
# 4 2779 2779
# 4 2780 2780
# 4 2781 2781
# 4 2782 2782
# 4 2783 2783
# 4 2784 2784
# 4 2785 2785
# 4 2786 2786
# 4 2787 2787
# 4 2788 2788
# 4 2789 2789
# 4 2790 2790
# 4 2791 2791
# 4 2792 2792
# 4 2793 2793
# 4 2794 2794
# 4 2795 2795
# 4 2796 2796
# 4 2797 2797
# 4 2798 2798
# 4 2799 2799
# 4 2800 2800
# End of iteration, temperature: 0.48767497911552943
# 4 2801 2801
# 4 2802 2802
# 4 2803 2803
# 4 2804 2804
# 4 2805 2805
# 4 2806 2806
# 4 2807 2807
# 4 2808 2808
# Accepted worse solution
# 6 2809 2809
# 6 2810 2810
# 6 2811 2811
# 6 2812 2812
# 6 2813 2813
# 6 2814 2814
# 6 2815 2815
# 6 2816 2816
# 6 2817 2817
# 6 2818 2818
# 6 2819 2819
# 6 2820 2820
# 6 2821 2821
# 6 2822 2822
# Accepted better solution
# 4 2823 2823
# 4 2824 2824
# 4 2825 2825
# 4 2826 2826
# 4 2827 2827
# 4 2828 2828
# 4 2829 2829
# 4 2830 2830
# 4 2831 2831
# 4 2832 2832
# 4 2833 2833
# 4 2834 2834
# 4 2835 2835
# 4 2836 2836
# 4 2837 2837
# 4 2838 2838
# 4 2839 2839
# 4 2840 2840
# 4 2841 2841
# Accepted better solution
# 2 2842 2842
# 2 2843 2843
# 2 2844 2844
# 2 2845 2845
# 2 2846 2846
# 2 2847 2847
# 2 2848 2848
# 2 2849 2849
# 2 2850 2850
# 2 2851 2851
# 2 2852 2852
# 2 2853 2853
# 2 2854 2854
# 2 2855 2855
# 2 2856 2856
# 2 2857 2857
# 2 2858 2858
# 2 2859 2859
# 2 2860 2860
# 2 2861 2861
# 2 2862 2862
# 2 2863 2863
# 2 2864 2864
# 2 2865 2865
# 2 2866 2866
# 2 2867 2867
# 2 2868 2868
# 2 2869 2869
# 2 2870 2870
# 2 2871 2871
# 2 2872 2872
# 2 2873 2873
# 2 2874 2874
# 2 2875 2875
# 2 2876 2876
# 2 2877 2877
# 2 2878 2878
# 2 2879 2879
# Accepted better solution
# Solution found
# Total loops: 2880
# [[2 5 3 9 1 4 6 8 7]
#  [6 8 9 3 7 2 5 1 4]
#  [7 1 4 8 5 6 2 9 3]
#  [1 4 2 6 9 7 8 3 5]
#  [5 3 8 4 2 1 9 7 6]
#  [9 6 7 5 3 8 4 2 1]
#  [8 7 1 2 6 5 3 4 9]
#  [3 2 6 7 4 9 1 5 8]
#  [4 9 5 1 8 3 7 6 2]]
# End of iteration, temperature: 0.46329123015975293
